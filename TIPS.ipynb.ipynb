# %%
# 📘 Tips Dataset EDA
# Author: MUHAMMAD HASEEB ASIR
# Date: 2025-05-11


# 📌 1. Import Libraries

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Set Seaborn style
sns.set(style="whitegrid")
# 📌 2. Load the Dataset

df = sns.load_dataset("tips")

# Display first few rows
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 📌 3. Basic Information

print("Shape of the dataset:", df.shape)
print("\nDataset Info:\n")
df.info()

# Check for missing values
print("\nMissing values:\n", df.isnull().sum())
# Out:
# Shape of the dataset: (244, 7)
#
# Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
#
# Missing values:
#  total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
# =============================
# 📌 4. Descriptive Statistics
# =============================
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# 📌 5. Univariate Analysis (Histograms)

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['total_bill'], bins=30, color='skyblue')
plt.title('Distribution of Total Bill')

plt.subplot(1, 2, 2)
sns.histplot(df['tip'], bins=30, color='salmon')
plt.title('Distribution of Tip')

plt.tight_layout()
plt.show()

# %%
# ======================================
# 📌 6. Count Plots for Categorical Data
# ======================================
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
sns.countplot(x='sex', data=df)
plt.title('Count by Sex')

plt.subplot(1, 3, 2)
sns.countplot(x='smoker', data=df)
plt.title('Count by Smoker')

plt.subplot(1, 3, 3)
sns.countplot(x='day', data=df)
plt.title('Count by Day')


plt.show()

# %%
# =========================
# 📌 7. Boxplots & Outliers
# =========================
plt.figure(figsize=(10, 6))
sns.boxplot(x='day', y='total_bill', data=df)
plt.title('Total Bill Distribution per Day')
plt.show()

# %%
# ===========================
# 📌 8. Relationship Analysis
# ===========================

# 💡 Tip vs Total Bill
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='total_bill', y='tip', hue='sex', style='smoker')
plt.title('Tip vs Total Bill')
plt.show()

# %%
# ===================================
# 📌 10. Pairplot (Multi-variable View)
# ===================================
sns.pairplot(df, hue='sex', palette='husl')
plt.suptitle("Pairplot of Tips Dataset", y=1.02)
plt.show()

# %%
# ===================
# 📌 11. Observations
# ===================
from IPython.display import Markdown

Markdown("""
### ✅ **Conclusion / Insights:**

1. **Total Bill** ranges mostly between \$10 and \$20.
2. **Tips** usually fall between \$1 and \$4, positively correlated with total bill.
3. **Male customers** are slightly more frequent than females in the dataset.
4. **Smokers vs. Non-smokers** are nearly balanced.
5. **Saturday and Sunday** have the most data — indicating busiest dining days.
6. **Tips increase with total bill**, but the rate is not perfectly linear.
7. **Slight gender variation** in tipping behavior, and smoker status may influence this.
8. **Outliers** exist in high bill/tip ranges (visible in boxplots and scatter plots).
9. The strongest numeric correlation is between **total bill and tip**.

This EDA gives a strong foundation to understand customer tipping behavior at the restaurant and could inform further predictive modeling or marketing strategy.
""")
# Out:
# ### ✅ **Conclusion / Insights:**
#
# 1. **Total Bill** ranges mostly between \$10 and \$20.
# 2. **Tips** usually fall between \$1 and \$4, positively correlated with total bill.
# 3. **Male customers** are slightly more frequent than females in the dataset.
# 4. **Smokers vs. Non-smokers** are nearly balanced.
# 5. **Saturday and Sunday** have the most data — indicating busiest dining days.
# 6. **Tips increase with total bill**, but the rate is not perfectly linear.
# 7. **Slight gender variation** in tipping behavior, and smoker status may influence this.
# 8. **Outliers** exist in high bill/tip ranges (visible in boxplots and scatter plots).
# 9. The strongest numeric correlation is between **total bill and tip**.
#
# This EDA gives a strong foundation to understand customer tipping behavior at the restaurant and could inform further predictive modeling or marketing strategy.
